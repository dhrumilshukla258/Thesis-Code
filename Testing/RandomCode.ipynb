# %%
#Read ImageFiles
matOfImages = np.zeros( (0,129602) ).astype(np.uint8)
for index, row in atl_183_1h.iterrows():
    imgName = row[0]
    img_cv = cv2.imread(imgName,cv2.IMREAD_UNCHANGED)  
    img_cv = cv2.resize(img_cv, (360,360))
    gray_cv = cv2.cvtColor(img_cv, cv2.COLOR_BGR2GRAY).flatten()
    alldata = np.append(gray_cv, [row[3],row[4]], 0)
    matOfImages = np.append( matOfImages, [alldata], axis = 0 )

# %%
''' 
    
    def GetLinkageMatrix(self, model):
        # Children of hierarchical clustering
        children = model.children_

        # Distances between each pair of children
        # Since we don't have this information, we can use a uniform one for plotting
        distance = np.arange(children.shape[0])
        
        # The number of observations contained in each cluster level
        no_of_observations = np.arange(2, children.shape[0]+2)

        # Create linkage matrix and then plot the dendrogram
        linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)
        
        return linkage_matrix
        
fig, axes= plt.subplots(nrows=1, ncols=1,figsize=(500,5))    
        dn = self.fancy_dendrogram(Z, 
                                ax=axes, 
                                orientation='top',
                                annotate_above=10,
                                show_leaf_counts = True,
                                leaf_rotation = 90,
                                leaf_font_size = 20
                               )
        plt.savefig(path+"dendrogram_level.png",format="png")

        
        #Z = linkage( method=link_m, metric=dist_m )

        self.k = agglo.n_clusters_
        self.labels = agglo.labels_
        self.n_leaves = agglo.n_leaves_
        self.n_connected_components = agglo.n_connected_components_

        for i in range(3,15):
            dn = dendrogram(linkage_matrix, 
                            ax=axes, 
                            truncate_mode='lastp', 
                            p=i, 
                            orientation='top',
                            c                            
                           )
            plt.savefig(path+"dendrogram_lastp_"+str(i)+".png",format="png")
            
            dn = dendrogram(linkage_matrix, 
                            ax=axes, 
                            truncate_mode='level', 
                            p=i, 
                            orientation='top',
                            show_leaf_counts = True,
                            leaf_rotation = 90,
                            leaf_font_size = 14
                           )
            plt.savefig(path+"dendrogram_level_"+str(i)+".png",format="png")
        
        
        #ward complete average single
        #if self.k == 0:
        #else:
        #agglo = AgglomerativeClustering(n_clusters=self.k,affinity=dist_m,linkage=link_m).fit(self.x)
        
        
        #truncate_mode='level', p=3
        #figure(num=None, figsize=(200, 200), dpi=144, facecolor='w', edgecolor='k')
        #plt.show()
        
     ----------------------------------------------------------------------------------------------------   
        
        def Scikit_Agglomerative(self, dist_m, link_m, dist_t, path, df):
        agglo = AgglomerativeClustering(n_clusters=None,
                                        affinity=dist_m,
                                        linkage=link_m,
                                        distance_threshold = dist_t,
                                       ).fit(self.x)
        
        linkage_matrix = self.GetLinkageMatrix(agglo)
        
        
        fig, axes= plt.subplots(nrows=1, ncols=1,figsize=(10,10))        
        
        for i in range(3,15):
            dn = self.fancy_dendrogram(Z, 
                            ax=axes, 
                            truncate_mode='lastp', 
                            p=i, 
                            orientation='top',
                            annotate_above=10,
                            show_leaf_counts = True,
                            leaf_rotation = 90,
                            leaf_font_size = 20
                           )
            #clusterPath 
            plt.savefig(path+"dendrogram_lastp_"+str(i)+".png",format="png")
        
        '''
        maxY = -math.inf
            minY = math.inf
            for j in dn['dcoord']:
                if maxY < j[1]:
                    maxY = j[1]
                if maxY < j[2]:
                    maxY = j[2]

                if minY > j[1]:
                    minY = j[1]
                if minY > j[2]:
                    minY = j[2]

        plt.xlabel("Number of points in node (or index of point if no parenthesis).")
        plt.ylim(minY-5,maxY+1)      
        plt.savefig(path+"dendrogram_lastp.png",format="png")
        
        '''
        plt.close()
        
        '''

# %%
import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):

    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting    
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dn = dendrogram(linkage_matrix, **kwargs)
    print(dn)

iris = load_iris()
x = iris.data[:20]
model = AgglomerativeClustering(linkage='ward',affinity="euclidean",n_clusters=5).fit(x)

plt.title('Hierarchical Clustering Dendrogram')

plot_dendrogram(model, 
                labels=model.labels_,
                orientation='top',
                p=5,
                truncate_mode='lastp',
                count_sort = "descending",
                distance_sort="descending"
               )
print(model.labels_)

# %%
Z = linkage(x,method='ward',metric="euclidean")
dn = dendrogram(Z,labels=model.labels_,orientation='top',p=5,truncate_mode='lastp')

# %%
apple = np.zeros((5,10000))
temp = []
for i in range(1,10001):
    temp.append(i)

apple[0] = temp
print(apple)

# %%
img_cv = cv2.imread("test.png")  
img_cv = cv2.resize(img_cv, (360,360))
gray = cv2.cvtColor(img_cv, cv2.COLOR_BGR2GRAY).flatten()
gray = gray.reshape(360,360)
gray = gray.astype(np.uint8)
img_cv = cv2.cvtColor(gray,cv2.COLOR_GRAY2RGB)
print(img_cv.shape)
# Output img with window name as 'image' 
cv2.imshow('image', img_cv)  
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from matplotlib import colors as mcolors
colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)
ccc = []
for k,v in colors.items():
    ccc.append(k)
